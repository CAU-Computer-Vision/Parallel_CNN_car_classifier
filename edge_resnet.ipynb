# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from PIL import Image
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, Sampler
import numpy as np
import cv2 as cv
import torchlayers as tl
import os

# %%
trans = transforms.Compose([transforms.Resize((120, 120)), transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
trans_gray = transforms.Compose([transforms.Resize((120, 120)), transforms.ToTensor(), transforms.Grayscale(3)])


# data = torchvision.datasets.ImageFolder(root = './data/kcar/lights', transform = trans)
# train_size = int(len(data) * 0.8)
# test_size = len(data) - train_size
# train_sets, test_sets = torch.utils.data.random_split(data, [train_size, test_size])

edge_data = torchvision.datasets.ImageFolder(root = './data/kcar_edge/lights', transform = trans_gray)
edge_train_size = int(len(edge_data) * 0.8)
edge_test_size = len(edge_data) - edge_train_size
train_sets, test_sets = torch.utils.data.random_split(edge_data, [edge_train_size, edge_test_size])

# edge_train_sets = torchvision.datasets.ImageFolder(root = './data/kcar_edge/lights', transform = trans)
test_sets_dark = torchvision.datasets.ImageFolder(root = './data/kcar_edge/darks', transform = trans)
# train_sets = torchvision.datasets.ImageFolder(root = './data/kcar/lights', transform = trans)
# test_sets_dark = torchvision.datasets.ImageFolder(root = './data/kcar/darks', transform = trans)
labels = edge_data.classes
# print(len(edge_train_sets))
print(len(test_sets_dark))
print(len(train_sets))
print(len(test_sets))
print(len(labels))
# print(test_sets)
# print(edge_test_sets)

# print(len(labels))
# for i in range(4):
#     img, label = train_sets[i]
#     print(labels[label])
#     plt.subplot(241 + i)
#     plt.imshow(np.clip(img.permute(1,2,0),0,1))
#     plt.tight_layout()
#     plt.show()
#     save_image(img, str(i)+'_.jpg')
# Out:
# 8657
# 26221
# 6556
# 51

# %%
# DataLoader 정의 - data 길이 달라지면 random_t_list 수정하기!
import random
random_train_list = list(range(1, len(train_sets)))
random.shuffle(random_train_list)
random_test_list = list(range(1, len(test_sets)))
random.shuffle(random_test_list)

train_loader = DataLoader(train_sets, batch_size = 32, num_workers = 2, sampler = random_train_list)
# edge_train_loader = DataLoader(edge_train_sets, batch_size = 32, num_workers = 2, sampler = random_train_list)
# print(len(train_loader))
test_loader = DataLoader(test_sets, batch_size = 32, sampler = random_test_list)
# test_loader_dark = DataLoader(test_sets_dark, batch_size = 32, sampler = random_test_list)
test_loader_dark = DataLoader(test_sets_dark, batch_size = 32, sampler = random_test_list)

# %%
def accuracy(output, target, topk=(1,)):
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)
 
        _, pred = output.topk(maxk, 1, True, True) #(52, 32)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred)) # (5,32)
 
        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res

# %%
resnet101 = torchvision.models.resnet101(pretrained=True)
resnet101 = resnet101.cuda()

# %%
#모델 학습
print(len(train_loader))
print(len(test_loader))

criterion = torch.nn.CrossEntropyLoss()
# optimizer = optim.Adam(resnet101.parameters(), lr=0.01)
# scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[3,6,8], gamma=0.1)
learning_rate = 1e-4
optimizer = optim.Adam(resnet101.parameters(), lr=learning_rate)

# hyper-parameters
num_epochs = 10
num_batches = 32

resnet101.train()
trn_loss_list = []
val_loss_list = []
val_loss_list_dark = []
for epoch in range(num_epochs):
    trn_loss = 0.0
    total = 0
    correct = 0
    for i, data in enumerate(train_loader):
        x, label = data

        x = x.cuda()
        label = label.cuda()
        # grad init
        optimizer.zero_grad()
        # forward propagation
        model_output = resnet101(x)               
        _, predicted = torch.max(model_output.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()
        # calculate loss
        loss = criterion(model_output, label)
        # back propagation 
        loss.backward()
        # weight update
        optimizer.step()
        
        # trn_loss summary
        trn_loss += loss.item()
        
        # 학습과정 출력
        if (i+1) % 100 == 1: # every 100 mini-batches
            resnet101.eval()
            with torch.no_grad(): # very very very very important!!!
                val_loss = 0.0
                val_total = 0
                val_correct = 0
                val_loss_dark = 0.0
                val_total_dark = 0
                val_correct_dark = 0
                
                count = 0
                for j, (val) in enumerate(test_loader):
                    count += 1
                    val_x, val_label = val
                    val_x = val_x.cuda()
                    val_label =val_label.cuda()

                    val_output = resnet101(val_x)
                    _, predicted = torch.max(val_output.data, 1)
                    val_total += val_label.size(0)
                    val_correct += (predicted == val_label).sum().item()
                    v_loss = criterion(val_output, val_label)
                    val_loss += v_loss
                    if count >= 3:
                        break
                for j, (val) in enumerate(test_loader_dark):
                    count += 1
                    val_x, val_label_dark = val
                    val_x = val_x.cuda()
                    val_label_dark =val_label_dark.cuda()

                    val_output_dark = resnet101(val_x)
                    _, predicted = torch.max(val_output_dark.data, 1)
                    val_total_dark += val_label_dark.size(0)
                    val_correct_dark += (predicted == val_label_dark).sum().item()
                    v_loss = criterion(val_output_dark, val_label_dark)
                    val_loss_dark += v_loss
                    if count >= 3:
                        break
               
                print("----------------testing data: "+ str(j * len(test_loader)))
                acc1, acc5 = accuracy(model_output, label, topk=(1, 5))
                print("train acc1 : {}, acc5 : {}".format(acc1[0], acc5[0])) 
                print('Accuracy of the network on the train images: %f %%' % (100 * correct / total))

                acc1, acc5 = accuracy(val_output, val_label, topk=(1, 5))
                print("test acc1 : {}, acc5 : {}".format(acc1[0], acc5[0]))
                print('Accuracy of the network on the test images: %f %%' % (100 * val_correct / val_total))

                acc1, acc5 = accuracy(val_output_dark, val_label_dark, topk=(1, 5))
                print("test acc1 : {}, acc5 : {}".format(acc1[0], acc5[0]))
                print('Accuracy of the network on the dark test images: %f %%' % (100 * val_correct_dark / val_total_dark))
                       
            print("epoch: {}/{} | step: {}/{} | trn loss: {:.4f} | val loss: {:.4f} | val_dark loss: {:.4f}".format(
                epoch+1, num_epochs, i+1, len(train_loader), trn_loss / len(train_loader), val_loss / 3, val_loss_dark / 3
            ))
                    
            
            trn_loss_list.append(trn_loss/len(train_loader))
            val_loss_list.append(val_loss/3)
            val_loss_list_dark.append(val_loss_dark/3)
            # val_loss_list.append(val_loss/len(test_loader))
            trn_loss = 0.0
            resnet101.train()
        
        # del (memory issue)
        # del lossadw
        del model_output
   # scheduler.step()
#plotting the loss chart
# Out:
# 820
# 205
# ----------------testing data: 0
# train acc1 : 0.0, acc5 : 0.0
# Accuracy of the network on the train images: 0.000000 %
# test acc1 : 0.0, acc5 : 0.0
# Accuracy of the network on the test images: 0.000000 %
# test acc1 : 0.0, acc5 : 0.0
# Accuracy of the network on the dark test images: 0.000000 %
# epoch: 1/10 | step: 1/820 | trn loss: 0.0127 | val loss: 15.2662 | val_dark loss: 5.8853
# ----------------testing data: 0
# train acc1 : 0.0, acc5 : 37.5
# Accuracy of the network on the train images: 6.002475 %
# test acc1 : 15.625, acc5 : 34.375
# Accuracy of the network on the test images: 13.541667 %
# test acc1 : 0.0, acc5 : 3.125
# Accuracy of the network on the dark test images: 0.000000 %
# epoch: 1/10 | step: 101/820 | trn loss: 0.6051 | val loss: 3.6188 | val_dark loss: 9.0891
# ----------------testing data: 0
# train acc1 : 31.25, acc5 : 56.25
# Accuracy of the network on the train images: 11.567164 %
# test acc1 : 28.125, acc5 : 65.625
# Accuracy of the network on the test images: 30.208333 %
# test acc1 : 0.0, acc5 : 3.125
# Accuracy of the network on the dark test images: 0.000000 %
# epoch: 1/10 | step: 201/820 | trn loss: 0.3850 | val loss: 2.6334 | val_dark loss: 6.3245
# ----------------testing data: 0
# train acc1 : 43.75, acc5 : 71.875
# Accuracy of the network on the train images: 17.919435 %
# test acc1 : 50.0, acc5 : 81.25
# Accuracy of the network on the test images: 41.666667 %
# test acc1 : 0.0, acc5 : 3.125
# Accuracy of the network on the dark test images: 0.000000 %
# epoch: 1/10 | step:
# ----------------testing data: 0
# train acc1 : 96.875, acc5 : 100.0
# Accuracy of the network on the train images: 97.413390 %
# test acc1 : 87.5, acc5 : 96.875
# Accuracy of the network on the test images: 88.541667 %
# test acc1 : 0.0, acc5 : 3.125
# Accuracy of the network on the dark test images: 0.000000 %
# epoch: 9/10 | step: 801/820 | trn loss: 0.0094 | val loss: 0.4507 | val_dark loss: 24.8797
# ----------------testing data: 0
# train acc1 : 96.875, acc5 : 100.0
# Accuracy of the network on the train images: 96.875000 %
# test acc1 : 90.625, acc5 : 96.875
# Accuracy of the network on the test images: 89.583333 %
# test acc1 : 0.0, acc5 : 3.125
# Accuracy of the network on the dark test images: 0.000000 %
# epoch: 10/10 | step: 1/820 | trn loss: 0.0001 | val loss: 0.4427 | val_dark loss: 18.9625
# ----------------testing data: 0
# train acc1 : 100.0, acc5 : 100.0
# Accuracy of the network on the train images: 97.555693 %
# test acc1 : 90.625, acc5 : 96.875
# Accuracy of the network on the test images: 90.625000 %
# test acc1 : 3.125, acc5 : 3.125
# Accuracy of the network on the dark test images: 3.125000 %
# epoch: 10/10 | step: 101/820 | trn loss: 0.0091 | val loss: 0.4718 | val_dark loss: 20.2118
# ----------------testing data: 0
# train acc1 : 93.75, acc5 : 100.0
# Accuracy of the network on the train images: 97.621269 %
# test acc1 : 84.375, acc5 : 100.0
# Accuracy of the network on the test images: 91.666667 %
# test acc1 : 3.125, acc5 : 3.125
# Accuracy of the network on the dark test images: 3.125000 %
# epoch: 10/10 | step: 201/820 | trn loss: 0.0093 | val loss: 0.3039 | val_dark loss: 19.6669
# ----------------testing data: 0
# train acc1 : 100.0, acc5 : 100.0
# Accuracy of the network on the train images: 97.549834 %
# test acc1 : 87.5, acc5 : 96.875
# Accuracy of the network on the test images: 88.541667 %
# test acc1 : 3.125, acc5 : 3.125
# Accuracy of the network on the dark test images: 3.125000 %
# epoch: 10/10 | step: 301/820 | trn loss: 0.0105 | val loss: 0.4850 | val_dark loss: 20.6118
# ----------------testing data: 0
# train acc1 : 96.875, acc5 : 100.0
# Accuracy of the network on the train images: 97.514027 %
# test acc1 : 90.625, acc5 : 96.875
# Accuracy of the network on the test images: 88.541667 %
# test acc1 : 3.125, acc5 : 3.125
# Accuracy of the network on the dark test images: 3.125000 %
# epoch: 10/10 | step: 401/820 | trn loss: 0.0093 | val loss: 0.5962 | val_dark loss: 13.6694
# ----------------testing data: 0
# train acc1 : 96.875, acc5 : 100.0
# Accuracy of the network on the train images: 97.392715 %
# test acc1 : 81.25, acc5 : 96.875
# Accuracy of the network on the test images: 88.541667 %
# test acc1 : 3.125, acc5 : 3.125
# Accuracy of the network on the dark test images: 3.125000 %
# epoch: 10/10 | step: 501/820 | trn loss: 0.0116 | val loss: 0.5563 | val_dark loss: 18.4853
# ----------------testing data: 0
# train acc1 : 100.0, acc5 : 100.0
# Accuracy of the network on the train images: 97.556156 %
# test acc1 : 81.25, acc5 : 100.0
# Accuracy of the network on the test images: 85.416667 %
# test acc1 : 3.125, acc5 : 3.125
# Accuracy of the network on the dark test images: 3.125000 %
# epoch: 10/10 | step: 601/820 | trn loss: 0.0066 | val loss: 0.4591 | val_dark loss: 13.3500
# ----------------testing data: 0
# train acc1 : 100.0, acc5 : 100.0
# Accuracy of the network on the train images: 97.606098 %
# test acc1 : 84.375, acc5 : 96.875
# Accuracy of the network on the test images: 85.416667 %
# test acc1 : 3.125, acc5 : 3.125
# Accuracy of the network on the dark test images: 3.125000 %
# epoch: 10/10 | step: 701/820 | trn loss: 0.0080 | val loss: 0.5830 | val_dark loss: 16.9686
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-fb6db1904151> in <module>
#      21     total = 0
#      22     correct = 0
# ---> 23     for i, data in enumerate(train_loader):
#      24         x, label = data
#      25
#
# ~\anaconda3\envs\venv\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\anaconda3\envs\venv\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#    1180
#    1181             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1182             idx, data = self._get_data()
#    1183             self._tasks_outstanding -= 1
#    1184             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~\anaconda3\envs\venv\lib\site-packages\torch\utils\data\dataloader.py in _get_data(self)
#    1146         else:
#    1147             while True:
# -> 1148                 success, data = self._try_get_data()
#    1149                 if success:
#    1150                     return data
#
# ~\anaconda3\envs\venv\lib\site-packages\torch\utils\data\dataloader.py in _try_get_data(self, timeout)
#     984         #   (bool: whether successfully get data, any: data if successful else None)
#     985         try:
# --> 986             data = self._data_queue.get(timeout=timeout)
#     987             return (True, data)
#     988         except Exception as e:
#
# ~\anaconda3\envs\venv\lib\multiprocessing\queues.py in get(self, block, timeout)
#     105                 if block:
#     106                     timeout = deadline - time.monotonic()
# --> 107                     if not self._poll(timeout):
#     108                         raise Empty
#     109                 elif not self._poll():
#
# ~\anaconda3\envs\venv\lib\multiprocessing\connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~\anaconda3\envs\venv\lib\multiprocessing\connection.py in _poll(self, timeout)
#     328                         _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     329                 return True
# --> 330             return bool(wait([self], timeout))
#     331
#     332         def _get_more_data(self, ov, maxsize):
#
# ~\anaconda3\envs\venv\lib\multiprocessing\connection.py in wait(object_list, timeout)
#     877                         timeout = 0
#     878
# --> 879             ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     880         finally:
#     881             # request that overlapped reads stop
#
# ~\anaconda3\envs\venv\lib\multiprocessing\connection.py in _exhaustive_wait(handles, timeout)
#     809         ready = []
#     810         while L:
# --> 811             res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     812             if res == WAIT_TIMEOUT:
#     813                 break
#
# KeyboardInterrupt:
